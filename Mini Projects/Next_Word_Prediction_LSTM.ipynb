# %%
data     = """About the Program
What is the fuel efficiency of the new electric car model?
The new electric car offers a fuel efficiency of 100 miles per charge.
What is the total number of petals in a sunflower?
A sunflower typically has 34, 55, or 89 petals arranged in a spiral pattern.
What is the lifespan of a garden gnome?
The lifespan of a garden gnome depends on the material but can range from 10 to 20 years if properly maintained.
Will the tulips bloom in winter?
No, tulips generally bloom in the spring and not during winter.
What if I forget to water my cactus? Will it survive?
Yes, most cacti are resilient and can survive for weeks without water.
Where can I find a good mechanic for my vintage car?
You can search for certified vintage car mechanics in your local area through online directories or car enthusiast forums.
What is the time required for a rose to fully bloom?
A rose typically takes about 6 to 8 weeks to fully bloom after planting.
What is the primary color of a marigold flower?
The primary color of a marigold flower is bright orange, although it can also be yellow or red.
How will I know when my apple tree is ready for harvest?
You will know your apple tree is ready for harvest when the apples easily detach from the tree with a slight twist.
Can I grow lavender indoors?
Yes, lavender can be grown indoors if provided with plenty of sunlight and proper drainage.
I am late, can I still attend the car show?
Absolutely, you can attend the car show at any time during the event.
If I miss the flower exhibition, will there be another one?
Yes, most flower exhibitions are annual, so you can attend the next one.
Where do I have to submit my gardening contest entry?
You don’t have to submit your entry in person; you can upload it on the contest’s official website.
Will there be a parade of classic cars at the festival?
Yes, the festival will feature a parade of classic cars on the final day.
Where can we contact the event organizers?
You can mail the event organizers at info@classicevents.com.
Payment/Registration Related Questions
Where do I have to make my payment for the car service?
You can make all your payments at the service center or through their online portal.
Can I pay for the bouquet in advance?
Unfortunately, no. The payment is required at the time of delivery.
What is the validity of the parking pass? Suppose if I purchase it on 15th March, do I have to renew it on 1st April or 15th April?
15th April. The parking pass is valid for 30 days from the day you purchase it.
What if I don’t like the floral arrangement after purchasing it? What is the refund policy?
You have a 7-day refund period from the day you received the floral arrangement.
I am living outside the city and cannot visit the plant nursery, what should I do?
You can contact the nursery and they will arrange for home delivery.
Post Registration Queries
Till when can I view the recorded car maintenance webinars?
You can view the recorded webinars until your subscription is valid. After the subscription expires, you will need to renew it to access the content.
Why is lifetime access to the gardening workshops not provided?
Because of the low course fee and the nature of the workshops.
Where can I reach out in case of a question about the flower planting guide?
You will have to fill out a contact form on the website, and our team will get back to you.
If I start growing roses late in the season, can I still get them to bloom?
Yes, but you may need to provide extra care and possibly use a greenhouse.
I am living outside the country and cannot attend the car expo, what should I do?
You can contact the expo organizers by sending an email to info@carexpo.com.
Certificate and Placement Assistance Related Questions
What is the criteria to get the certificate of participation for the classic car show?
There are two criteria:
You have to register for the event.
You have to display your vehicle in the show.
I am joining the gardening course late. How can I catch up on the missed content?
You will get access to all the previous sessions and materials in your dashboard once you register.
I have read that there is assistance for finding rare car parts. What does that include?
This assistance does not guarantee finding parts, but includes:
Networking sessions with other collectors
Access to a database of suppliers
Tips for maintaining and restoring vintage vehicles
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([data])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'i': 2,
#  'can': 3,
#  'to': 4,
#  'you': 5,
#  'a': 6,
#  'of': 7,
#  'is': 8,
#  'for': 9,
#  'what': 10,
#  'car': 11,
#  'will': 12,
#  'and': 13,
#  'in': 14,
#  'have': 15,
#  'it': 16,
#  'on': 17,
#  'if': 18,
#  'your': 19,
#  'or': 20,
#  'bloom': 21,
#  'my': 22,
#  'yes': 23,
#  'where': 24,
#  'flower': 25,
#  'at': 26,
#  'do': 27,
#  'from': 28,
#  'be': 29,
#  'am': 30,
#  'attend': 31,
#  'show': 32,
#  'event': 33,
#  'there': 34,
#  'day': 35,
#  'contact': 36,
#  'access': 37,
#  'get': 38,
#  'about': 39,
#  'but': 40,
#  'not': 41,
#  'are': 42,
#  'vintage': 43,
#  'time': 44,
#  'after': 45,
#  'when': 46,
#  'tree': 47,
#  'with': 48,
#  'late': 49,
#  'gardening': 50,
#  'classic': 51,
#  'organizers': 52,
#  'payment': 53,
#  '15th': 54,
#  'april': 55,
#  'assistance': 56,
#  'fuel': 57,
#  'efficiency': 58,
#  'new': 59,
#  'electric': 60,
#  'petals': 61,
#  'sunflower': 62,
#  'typically': 63,
#  'lifespan': 64,
#  'garden': 65,
# ...

# %%
for sentence in data.split("\n"):
    print(sentence)
# Out:
# About the Program
# What is the fuel efficiency of the new electric car model?
# The new electric car offers a fuel efficiency of 100 miles per charge.
# What is the total number of petals in a sunflower?
# A sunflower typically has 34, 55, or 89 petals arranged in a spiral pattern.
# What is the lifespan of a garden gnome?
# The lifespan of a garden gnome depends on the material but can range from 10 to 20 years if properly maintained.
# Will the tulips bloom in winter?
# No, tulips generally bloom in the spring and not during winter.
# What if I forget to water my cactus? Will it survive?
# Yes, most cacti are resilient and can survive for weeks without water.
# Where can I find a good mechanic for my vintage car?
# You can search for certified vintage car mechanics in your local area through online directories or car enthusiast forums.
# What is the time required for a rose to fully bloom?
# A rose typically takes about 6 to 8 weeks to fully bloom after planting.
# ...

# %%
input_sequence = []
for sentence in data.split("\n"):
    tokens = (tokenizer.texts_to_sequences([sentence])[0])

    for i in range(1,len(tokens)):
      input_sequence.append(tokens[:i+1])

# %%
input_sequence
# Out:
# [[39, 1],
#  [39, 1, 141],
#  [10, 8],
#  [10, 8, 1],
#  [10, 8, 1, 57],
#  [10, 8, 1, 57, 58],
#  [10, 8, 1, 57, 58, 7],
#  [10, 8, 1, 57, 58, 7, 1],
#  [10, 8, 1, 57, 58, 7, 1, 59],
#  [10, 8, 1, 57, 58, 7, 1, 59, 60],
#  [10, 8, 1, 57, 58, 7, 1, 59, 60, 11],
#  [10, 8, 1, 57, 58, 7, 1, 59, 60, 11, 142],
#  [1, 59],
#  [1, 59, 60],
#  [1, 59, 60, 11],
#  [1, 59, 60, 11, 143],
#  [1, 59, 60, 11, 143, 6],
#  [1, 59, 60, 11, 143, 6, 57],
#  [1, 59, 60, 11, 143, 6, 57, 58],
#  [1, 59, 60, 11, 143, 6, 57, 58, 7],
#  [1, 59, 60, 11, 143, 6, 57, 58, 7, 144],
#  [1, 59, 60, 11, 143, 6, 57, 58, 7, 144, 145],
#  [1, 59, 60, 11, 143, 6, 57, 58, 7, 144, 145, 146],
#  [1, 59, 60, 11, 143, 6, 57, 58, 7, 144, 145, 146, 147],
#  [10, 8],
#  [10, 8, 1],
#  [10, 8, 1, 148],
#  [10, 8, 1, 148, 149],
#  [10, 8, 1, 148, 149, 7],
#  [10, 8, 1, 148, 149, 7, 61],
#  [10, 8, 1, 148, 149, 7, 61, 14],
#  [10, 8, 1, 148, 149, 7, 61, 14, 6],
#  [10, 8, 1, 148, 149, 7, 61, 14, 6, 62],
#  [6, 62],
# ...

# %%
max_len = max([len(x) for x in input_sequence])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded = pad_sequences(input_sequence, maxlen = max_len , padding = 'pre')

# %%
padded
# Out:
# array([[  0,   0,   0, ...,   0,  39,   1],
#        [  0,   0,   0, ...,  39,   1, 141],
#        [  0,   0,   0, ...,   0,  10,   8],
#        ...,
#        [  0,   0,   0, ..., 312,  13, 313],
#        [  0,   0,   0, ...,  13, 313,  43],
#        [  0,   0,   0, ..., 313,  43, 314]], dtype=int32)

# %%
X = padded[:,:-1]

# %%
Y = padded[:,-1]

# %%
X.shape
# Out:
# (733, 27)

# %%
Y.shape
# Out:
# (733,)

# %%
len(tokenizer.word_index)
# Out:
# 314

# %%
from tensorflow.keras.utils import to_categorical
Y = to_categorical(Y,num_classes=315)

# %%
Y.shape
# Out:
# (733, 315)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense

#LSTM Model
model = Sequential()
model.add(Embedding(input_dim=315, output_dim=100, input_length=27))
model.add(LSTM(150, return_sequences=True, input_shape=(27, 100))) # return_sequences is an argument for LSTM not model.add
model.add(LSTM(150))

model.add(Dense(315, activation='softmax'))

model.build(input_shape= (None, 27))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 27, 100)             │          31,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 27, 150)             │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 150)                 │         180,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 315)                 │          47,565 │
# ...

# %%
model.fit(X,Y,epochs=100)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.0649 - loss: 5.6549
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.0940 - loss: 5.1400
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0735 - loss: 5.1869
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0829 - loss: 5.1516
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0934 - loss: 5.0774
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0790 - loss: 5.1448
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0934 - loss: 5.0146
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0941 - loss: 5.0011
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0816 - loss: 4.9023
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0763 - loss: 4.8076
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0819 - loss: 4.6762
# Epoch 12/100
# ...

# %%
import time
import numpy as np
text = "what is the fee"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# what is the fee to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# what is the fee to get
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# what is the fee to get the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# what is the fee to get the certificate
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# what is the fee to get the certificate of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# what is the fee to get the certificate of participation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# what is the fee to get the certificate of participation of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# what is the fee to get the certificate of participation of the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# what is the fee to get the certificate of participation of the classic
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# what is the fee to get the certificate of participation of the classic car

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'i': 2,
#  'can': 3,
#  'to': 4,
#  'you': 5,
#  'a': 6,
#  'of': 7,
#  'is': 8,
#  'for': 9,
#  'what': 10,
#  'car': 11,
#  'will': 12,
#  'and': 13,
#  'in': 14,
#  'have': 15,
#  'it': 16,
#  'on': 17,
#  'if': 18,
#  'your': 19,
#  'or': 20,
#  'bloom': 21,
#  'my': 22,
#  'yes': 23,
#  'where': 24,
#  'flower': 25,
#  'at': 26,
#  'do': 27,
#  'from': 28,
#  'be': 29,
#  'am': 30,
#  'attend': 31,
#  'show': 32,
#  'event': 33,
#  'there': 34,
#  'day': 35,
#  'contact': 36,
#  'access': 37,
#  'get': 38,
#  'about': 39,
#  'but': 40,
#  'not': 41,
#  'are': 42,
#  'vintage': 43,
#  'time': 44,
#  'after': 45,
#  'when': 46,
#  'tree': 47,
#  'with': 48,
#  'late': 49,
#  'gardening': 50,
#  'classic': 51,
#  'organizers': 52,
#  'payment': 53,
#  '15th': 54,
#  'april': 55,
#  'assistance': 56,
#  'fuel': 57,
#  'efficiency': 58,
#  'new': 59,
#  'electric': 60,
#  'petals': 61,
#  'sunflower': 62,
#  'typically': 63,
#  'lifespan': 64,
#  'garden': 65,
# ...
